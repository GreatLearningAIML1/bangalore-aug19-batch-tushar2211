# %% [markdown]
# # The Iris Dataset
# The data set consists of 50 samples from each of three species of Iris (Iris setosa, Iris virginica and Iris versicolor). Four features were measured from each sample: the length and the width of the sepals and petals, in centimeters.
#
# The dataset contains a set of 150 records under five attributes - petal length, petal width, sepal length, sepal width and species.

# %%
import pandas as pd
import numpy as np
from sklearn.datasets import load_iris
irisdata = load_iris()

# %% [markdown]
# ### Specifying the TensorFlow version
# Running `import tensorflow` will import the default version (currently 1.x). You can use 2.x by running a cell with the `tensorflow_version` magic **before** you run `import tensorflow`.

# %%
# %tensorflow_version 2.x
# Out:
# TensorFlow 2.x selected.

# %% [markdown]
# ### Import TensorFlow
# Once you have specified a version via this magic, you can run `import tensorflow` as normal and verify which version was imported as follows:

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.1.0-rc1

# %% [markdown]
# ### Set random seed

# %%
tf.random.set_seed(42)

# %% [markdown]
# ## Question 1

# %% [markdown]
# ### Import dataset
# - Import iris dataset
# - Import the dataset using sklearn library

# %%
import pandas as pd
import numpy as np
from sklearn.datasets import load_iris
irisdata = load_iris()

# %% [markdown]
# ## Question 2

# %% [markdown]
# ### Get features and label from the dataset in separate variable
# - you can get the features using .data method
# - you can get the features using .target method

# %%
X = irisdata.data

# %%
y = irisdata.target

# %%
X.shape
# Out:
# (150, 4)

# %%
y.shape
# Out:
# (150,)

# %% [markdown]
# ## Question 3

# %% [markdown]
# ```
# # This is formatted as code
# ```
#
# ### Create train and test data
# - use train_test_split to get train and test set
# - set a random_state
# - test_size: 0.25

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.25, random_state=1)
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (112, 4)
# (112,)
# (38, 4)
# (38,)

# %% [markdown]
# ## Question 4

# %% [markdown]
# ### One-hot encode the labels
# - convert class vectors (integers) to binary class matrix
# - convert labels
# - number of classes: 3
# - we are doing this to use categorical_crossentropy as loss

# %%
from keras.utils import to_categorical
y_test=to_categorical(y_test, num_classes=3)
y_train=to_categorical(y_train, num_classes=3)
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## Question 5

# %% [markdown]
# ### Initialize a sequential model
# - Define a sequential model

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
model = tf.keras.Sequential()

# %% [markdown]
# ## Question 6

# %% [markdown]
# ### Add a layer
# - Use Dense Layer  with input shape of 4 (according to the feature set) and number of outputs set to 3
# - Apply Softmax on Dense Layer outputs

# %%
# Add an input layer  
model.add(Dense(4, activation='sigmoid', input_shape=(4,)))   

# Add an output layer  
model.add(Dense(3, activation='softmax'))

# %% [markdown]
# ## Question 7

# %% [markdown]
# ### Compile the model
# - Use SGD as Optimizer
# - Use categorical_crossentropy as loss function
# - Use accuracy as metrics

# %%
model.compile(optimizer='SGD', loss='categorical_crossentropy', metrics=['accuracy'])

# %% [markdown]
# ## Question 8

# %% [markdown]
# ### Summarize the model
# - Check model layers
# - Understand number of trainable parameters

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_4 (Dense)              (None, 4)                 20
# _________________________________________________________________
# dense_5 (Dense)              (None, 3)                 15
# =================================================================
# Total params: 35
# Trainable params: 35
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Question 9

# %% [markdown]
# ### Fit the model
# - Give train data as training features and labels
# - Epochs: 100
# - Give validation data as testing features and labels

# %%
history=model.fit(X_train, y_train, epochs=100, batch_size=1, verbose=1)
# Out:
# Train on 112 samples
# Epoch 1/100
# 112/112 [==============================] - 0s 3ms/sample - loss: 0.9170 - accuracy: 0.6250
# Epoch 2/100
# 112/112 [==============================] - 0s 1ms/sample - loss: 0.7903 - accuracy: 0.6964
# Epoch 3/100
# 112/112 [==============================] - 0s 1ms/sample - loss: 0.7370 - accuracy: 0.7321
# Epoch 4/100
# 112/112 [==============================] - 0s 1ms/sample - loss: 0.6922 - accuracy: 0.7589
# Epoch 5/100
# 112/112 [==============================] - 0s 1ms/sample - loss: 0.6537 - accuracy: 0.7143
# Epoch 6/100
# 112/112 [==============================] - 0s 1ms/sample - loss: 0.6216 - accuracy: 0.7857
# Epoch 7/100
# 112/112 [==============================] - 0s 1ms/sample - loss: 0.5985 - accuracy: 0.7321
# Epoch 8/100
# 112/112 [==============================] - 0s 1ms/sample - loss: 0.5748 - accuracy: 0.7768
# Epoch 9/100
# 112/112 [==============================] - 0s 1ms/sample - loss: 0.5537 - accuracy: 0.7857
# Epoch 10/100
# 112/112 [==============================] - 0s 1ms/sample - loss: 0.5385 - accuracy: 0.7946
# Epoch 11/100
# 112/112 [==============================] - 0s 1ms/sample - loss: 0.5200 - accuracy: 0.8214
# Epoch 12/100
# 112/112 [==============================] - 0s 1ms/sample - loss: 0.5083 - accuracy: 0.7768
# Epoch 13/100
# 112/112 [==============================] - 0s 1ms/sample - loss: 0.4894 - accuracy: 0.8036
# Epoch 14/100
# 112/112 [==============================] - 0s 1ms/sample - loss: 0.4826 - accuracy: 0.8393
# Epoch 15/100
# 112/112 [==============================] - 0s 1ms/sample - loss: 0.4700 - accuracy: 0.8571
# Epoch 16/100
# 112/112 [==============================] - 0s 1ms/sample - loss: 0.4591 - accuracy: 0.8214
# Epoch 17/100
# 112/112 [==============================] - 0s 1ms/sample - loss: 0.4436 - accuracy: 0.8661
# Epoch 18/100
# 112/112 [==============================] - 0s 1ms/sample - loss: 0.4406 - accuracy: 0.8750
# Epoch 19/100
# 112/112 [==============================] - 0s 1ms/sample - loss: 0.4200 - accuracy: 0.8839
# Epoch 20/100
# 112/112 [==============================] - 0s 1ms/sample - loss: 0.4179 - accuracy: 0.9286
# Epoch 21/100
# 112/112 [==============================] - 0s 1ms/sample - loss: 0.4114 - accuracy: 0.9286
# Epoch 22/100
# 112/112 [==============================] - 0s 1ms/sample - loss: 0.3996 - accuracy: 0.9286
# Epoch 23/100
# 112/112 [==============================] - 0s 1ms/sample - loss: 0.3931 - accuracy: 0.8929
# Epoch 24/100
# 112/112 [==============================] - 0s 1ms/sample - loss: 0.3811 - accuracy: 0.9375
# Epoch 25/100
# 112/112 [==============================] - 0s 1ms/sample - loss: 0.3770 - accuracy: 0.9286
# Epoch 26/100
# 112/112 [==============================] - 0s 1ms/sample - loss: 0.3674 - accuracy: 0.9107
# Epoch 27/100
# 112/112 [==============================] - 0s 1ms/sample - loss: 0.3560 - accuracy: 0.9464
# Epoch 28/100
# 112/112 [==============================] - 0s 1ms/sample - loss: 0.3412 - accuracy: 0.9554
# Epoch 29/100
# 112/112 [==============================] - 0s 1ms/sample - loss: 0.3481 - accuracy: 0.9196
# Epoch 30/100
# 112/112 [==============================] - 0s 1ms/sample - loss: 0.3360 - accuracy: 0.9286
# Epoch 31/100
# 112/112 [==============================] - 0s 1ms/sample - loss: 0.3278 - accuracy: 0.9464
# Epoch 32/100
# 112/112 [==============================] - 0s 1ms/sample - loss: 0.3205 - accuracy: 0.9375
# Epoch 33/100
# 112/112 [==============================] - 0s 1ms/sample - loss: 0.3137 - accuracy: 0.9554
# Epoch 34/100
# 112/112 [==============================] - 0s 1ms/sample - loss: 0.3027 - accuracy: 0.9375
# Epoch 35/100
# 112/112 [==============================] - 0s 1ms/sample - loss: 0.3006 - accuracy: 0.9375
# Epoch 36/100
# 112/112 [==============================] - 0s 1ms/sample - loss: 0.2951 - accuracy: 0.9286
# Epoch 37/100
# 112/112 [==============================] - 0s 1ms/sample - loss: 0.2871 - accuracy: 0.9643
# Epoch 38/100
# 112/112 [==============================] - 0s 1ms/sample - loss: 0.2815 - accuracy: 0.9464
# Epoch 39/100
# 112/112 [==============================] - 0s 1ms/sample - loss: 0.2764 - accuracy: 0.9375
# Epoch 40/100
# 112/112 [==============================] - 0s 1ms/sample - loss: 0.2682 - accuracy: 0.9643
# Epoch 41/100
# 112/112 [==============================] - 0s 1ms/sample - loss: 0.2683 - accuracy: 0.9554
# Epoch 42/100
# 112/112 [==============================] - 0s 1ms/sample - loss: 0.2605 - accuracy: 0.9643
# Epoch 43/100
# 112/112 [==============================] - 0s 1ms/sample - loss: 0.2545 - accuracy: 0.9554
# Epoch 44/100
# 112/112 [==============================] - 0s 1ms/sample - loss: 0.2546 - accuracy: 0.9554
# Epoch 45/100
# 112/112 [==============================] - 0s 1ms/sample - loss: 0.2481 - accuracy: 0.9554
# Epoch 46/100
# 112/112 [==============================] - 0s 1ms/sample - loss: 0.2428 - accuracy: 0.9464
# Epoch 47/100
# 112/112 [==============================] - 0s 1ms/sample - loss: 0.2312 - accuracy: 0.9732
# Epoch 48/100
# 112/112 [==============================] - 0s 1ms/sample - loss: 0.2272 - accuracy: 0.9732
# Epoch 49/100
# 112/112 [==============================] - 0s 1ms/sample - loss: 0.2340 - accuracy: 0.9643
# Epoch 50/100
# 112/112 [==============================] - 0s 1ms/sample - loss: 0.2288 - accuracy: 0.9554
# Epoch 51/100
# 112/112 [==============================] - 0s 1ms/sample - loss: 0.2210 - accuracy: 0.9464
# Epoch 52/100
# 112/112 [==============================] - 0s 1ms/sample - loss: 0.2231 - accuracy: 0.9643
# Epoch 53/100
# 112/112 [==============================] - 0s 1ms/sample - loss: 0.2180 - accuracy: 0.9643
# Epoch 54/100
# 112/112 [==============================] - 0s 1ms/sample - loss: 0.2123 - accuracy: 0.9732
# Epoch 55/100
# 112/112 [==============================] - 0s 1ms/sample - loss: 0.2122 - accuracy: 0.9554
# Epoch 56/100
# 112/112 [==============================] - 0s 1ms/sample - loss: 0.2104 - accuracy: 0.9643
# Epoch 57/100
# 112/112 [==============================] - 0s 1ms/sample - loss: 0.2020 - accuracy: 0.9554
# Epoch 58/100
# 112/112 [==============================] - 0s 1ms/sample - loss: 0.2044 - accuracy: 0.9554
# Epoch 59/100
# 112/112 [==============================] - 0s 1ms/sample - loss: 0.2013 - accuracy: 0.9732
# Epoch 60/100
# 112/112 [==============================] - 0s 1ms/sample - loss: 0.1967 - accuracy: 0.9643
# Epoch 61/100
# 112/112 [==============================] - 0s 1ms/sample - loss: 0.1943 - accuracy: 0.9554
# Epoch 62/100
# 112/112 [==============================] - 0s 1ms/sample - loss: 0.1904 - accuracy: 0.9554
# Epoch 63/100
# 112/112 [==============================] - 0s 1ms/sample - loss: 0.1851 - accuracy: 0.9732
# Epoch 64/100
# 112/112 [==============================] - 0s 1ms/sample - loss: 0.1842 - accuracy: 0.9554
# Epoch 65/100
# 112/112 [==============================] - 0s 1ms/sample - loss: 0.1879 - accuracy: 0.9554
# Epoch 66/100
# 112/112 [==============================] - 0s 1ms/sample - loss: 0.1827 - accuracy: 0.9554
# Epoch 67/100
# 112/112 [==============================] - 0s 1ms/sample - loss: 0.1777 - accuracy: 0.9643
# Epoch 68/100
# 112/112 [==============================] - 0s 1ms/sample - loss: 0.1712 - accuracy: 0.9732
# Epoch 69/100
# 112/112 [==============================] - 0s 1ms/sample - loss: 0.1851 - accuracy: 0.9643
# Epoch 70/100
# 112/112 [==============================] - 0s 1ms/sample - loss: 0.1786 - accuracy: 0.9554
# Epoch 71/100
# 112/112 [==============================] - 0s 1ms/sample - loss: 0.1713 - accuracy: 0.9732
# Epoch 72/100
# 112/112 [==============================] - 0s 1ms/sample - loss: 0.1690 - accuracy: 0.9732
# Epoch 73/100
# 112/112 [==============================] - 0s 1ms/sample - loss: 0.1728 - accuracy: 0.9732
# Epoch 74/100
# 112/112 [==============================] - 0s 1ms/sample - loss: 0.1601 - accuracy: 0.9643
# Epoch 75/100
# 112/112 [==============================] - 0s 1ms/sample - loss: 0.1695 - accuracy: 0.9643
# Epoch 76/100
# 112/112 [==============================] - 0s 1ms/sample - loss: 0.1637 - accuracy: 0.9643
# Epoch 77/100
# 112/112 [==============================] - 0s 1ms/sample - loss: 0.1655 - accuracy: 0.9732
# Epoch 78/100
# 112/112 [==============================] - 0s 1ms/sample - loss: 0.1646 - accuracy: 0.9554
# Epoch 79/100
# 112/112 [==============================] - 0s 1ms/sample - loss: 0.1572 - accuracy: 0.9643
# Epoch 80/100
# 112/112 [==============================] - 0s 1ms/sample - loss: 0.1634 - accuracy: 0.9643
# Epoch 81/100
# 112/112 [==============================] - 0s 1ms/sample - loss: 0.1606 - accuracy: 0.9643
# Epoch 82/100
# 112/112 [==============================] - 0s 1ms/sample - loss: 0.1538 - accuracy: 0.9732
# Epoch 83/100
# 112/112 [==============================] - 0s 1ms/sample - loss: 0.1604 - accuracy: 0.9464
# Epoch 84/100
# 112/112 [==============================] - 0s 1ms/sample - loss: 0.1572 - accuracy: 0.9643
# Epoch 85/100
# 112/112 [==============================] - 0s 1ms/sample - loss: 0.1571 - accuracy: 0.9732
# Epoch 86/100
# 112/112 [==============================] - 0s 1ms/sample - loss: 0.1563 - accuracy: 0.9732
# Epoch 87/100
# 112/112 [==============================] - 0s 1ms/sample - loss: 0.1556 - accuracy: 0.9643
# Epoch 88/100
# 112/112 [==============================] - 0s 1ms/sample - loss: 0.1475 - accuracy: 0.9643
# Epoch 89/100
# 112/112 [==============================] - 0s 1ms/sample - loss: 0.1474 - accuracy: 0.9643
# Epoch 90/100
# 112/112 [==============================] - 0s 1ms/sample - loss: 0.1485 - accuracy: 0.9732
# Epoch 91/100
# 112/112 [==============================] - 0s 1ms/sample - loss: 0.1490 - accuracy: 0.9643
# Epoch 92/100
# 112/112 [==============================] - 0s 1ms/sample - loss: 0.1431 - accuracy: 0.9732
# Epoch 93/100
# 112/112 [==============================] - 0s 1ms/sample - loss: 0.1424 - accuracy: 0.9643
# Epoch 94/100
# 112/112 [==============================] - 0s 1ms/sample - loss: 0.1480 - accuracy: 0.9732
# Epoch 95/100
# 112/112 [==============================] - 0s 1ms/sample - loss: 0.1427 - accuracy: 0.9554
# Epoch 96/100
# 112/112 [==============================] - 0s 1ms/sample - loss: 0.1439 - accuracy: 0.9732
# Epoch 97/100
# 112/112 [==============================] - 0s 1ms/sample - loss: 0.1425 - accuracy: 0.9554
# Epoch 98/100
# 112/112 [==============================] - 0s 1ms/sample - loss: 0.1404 - accuracy: 0.9732
# Epoch 99/100
# 112/112 [==============================] - 0s 1ms/sample - loss: 0.1467 - accuracy: 0.9643
# Epoch 100/100
# 112/112 [==============================] - 0s 1ms/sample - loss: 0.1440 - accuracy: 0.9643

# %% [markdown]
# ## Question 10

# %% [markdown]
# ### Make predictions
# - Predict labels on one row

# %%
np.round(model.predict(X_test[0:1]))
# Out:
# array([[1., 0., 0.]], dtype=float32)

# %% [markdown]
# ### Compare the prediction with actual label
# - Print the same row as done in the previous step but of actual labels

# %%
y_test[0:1]
# Out:
# array([[1., 0., 0.]], dtype=float32)

# %% [markdown]
# ---

# %%
score=model.evaluate(X_test,y_test)
# Out:
# 38/38 [==============================] - 0s 2ms/sample - loss: 0.1552 - accuracy: 0.9737

# %%
score
# Out:
# [0.15524759614153913, 0.9736842]

# %%
y_predict = model.predict(X_test)

# %%
y_predict[0]
# Out:
# array([9.7837603e-01, 2.1414869e-02, 2.0914720e-04], dtype=float32)

# %%
y_pred = np.round(model.predict(X_test))
y_pred[0:1]
# Out:
# array([[1., 0., 0.]], dtype=float32)

# %% [markdown]
# # Stock prices dataset
# The data is of stock exchange's stock listings for each trading day of 2010 to 2016.
#
# ## Description
# A brief description of columns.
# - open: The opening market price of the equity symbol on the date
# - high: The highest market price of the equity symbol on the date
# - low: The lowest recorded market price of the equity symbol on the date
# - close: The closing recorded price of the equity symbol on the date
# - symbol: Symbol of the listed company
# - volume: Total traded volume of the equity symbol on the date
# - date: Date of record

# %% [markdown]
# ### Specifying the TensorFlow version
# Running `import tensorflow` will import the default version (currently 1.x). You can use 2.x by running a cell with the `tensorflow_version` magic **before** you run `import tensorflow`.

# %%
# %tensorflow_version 2.x

# %% [markdown]
# ### Import TensorFlow
# Once you have specified a version via this magic, you can run `import tensorflow` as normal and verify which version was imported as follows:

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.1.0-rc1

# %% [markdown]
# ### Set random seed

# %%
tf.random.set_seed(42)

# %% [markdown]
# ## Question 1

# %% [markdown]
# ### Load the data
# - load the csv file and read it using pandas
# - file name is prices.csv

# %%
# run this cell to upload file if you are using google colab
from google.colab import files
files.upload()

#drive.mount('/content/gdrive')
# Out:
#      <input type="file" id="files-e09c46d9-00a4-40ab-8baf-f177bd4272c1" name="files[]" multiple disabled />
#      <output id="result-e09c46d9-00a4-40ab-8baf-f177bd4272c1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving prices.csv to prices (1).csv

# %%
import io
import pandas as pd
import numpy as np
prices = pd.read_csv('prices.csv')

# %%
prices.shape
# Out:
# (851264, 7)

# %%
prices.head()
# Out:
#                   date symbol        open  ...         low        high     volume
# 0  2016-01-05 00:00:00   WLTW  123.430000  ...  122.309998  126.250000  2163600.0
# 1  2016-01-06 00:00:00   WLTW  125.239998  ...  119.940002  125.540001  2386400.0
# 2  2016-01-07 00:00:00   WLTW  116.379997  ...  114.930000  119.739998  2489500.0
# 3  2016-01-08 00:00:00   WLTW  115.480003  ...  113.500000  117.440002  2006300.0
# 4  2016-01-11 00:00:00   WLTW  117.010002  ...  114.089996  117.330002  1408600.0
#
# [5 rows x 7 columns]

# %%
prices.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 851264 entries, 0 to 851263
# Data columns (total 7 columns):
# date      851264 non-null object
# symbol    851264 non-null object
# open      851264 non-null float64
# close     851264 non-null float64
# low       851264 non-null float64
# high      851264 non-null float64
# volume    851264 non-null float64
# dtypes: float64(5), object(2)
# memory usage: 45.5+ MB

# %%
prices.describe()
# Out:
#                 open          close            low           high        volume
# count  851264.000000  851264.000000  851264.000000  851264.000000  8.512640e+05
# mean       70.836986      70.857109      70.118414      71.543476  5.415113e+06
# std        83.695876      83.689686      82.877294      84.465504  1.249468e+07
# min         0.850000       0.860000       0.830000       0.880000  0.000000e+00
# 25%        33.840000      33.849998      33.480000      34.189999  1.221500e+06
# 50%        52.770000      52.799999      52.230000      53.310001  2.476250e+06
# 75%        79.879997      79.889999      79.110001      80.610001  5.222500e+06
# max      1584.439941    1578.130005    1549.939941    1600.930054  8.596434e+08

# %% [markdown]
# ## Question 2

# %% [markdown]
# ### Drop columnns
# - drop "date" and "symbol" column from the data

# %%
prices_new = prices.drop(['date', 'symbol'], axis=1)
#prices1 = prices1.drop("symbol", axis=1)

# %%
prices_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 851264 entries, 0 to 851263
# Data columns (total 5 columns):
# open      851264 non-null float64
# close     851264 non-null float64
# low       851264 non-null float64
# high      851264 non-null float64
# volume    851264 non-null float64
# dtypes: float64(5)
# memory usage: 32.5 MB

# %% [markdown]
# ## Question 3

# %% [markdown]
# ### Take initial rows
# - Take first 1000 rows from the data
# - This step is done to make the execution faster

# %%
prices_new2 = prices_new.head(1000)

# %%
prices_new.shape
# Out:
# (851264, 5)

# %%
prices_new2.shape
# Out:
# (1000, 5)

# %% [markdown]
# ## Question 4

# %% [markdown]
# ### Get features and label from the dataset in separate variable
# - Take "open", "close", "low", "high" columns as features
# - Take "volume" column as label
# - Normalize label column by dividing it with 1000000

# %%
# Seperation of features and target column as given above
X = prices_new2.drop("volume" , axis=1)

y = prices_new2['volume']

# %%
X.shape
# Out:
# (1000, 4)

# %%
y.shape
# Out:
# (1000,)

# %%
#Normalize label column by dividing it with 1000000
y.describe()
# Out:
# count    1.000000e+03
# mean     5.314222e+06
# std      1.446565e+07
# min      1.000000e+04
# 25%      8.216250e+05
# 50%      2.064450e+06
# 75%      4.620475e+06
# max      2.156202e+08
# Name: volume, dtype: float64

# %%
y1 = y/1000000

# %%
y1.describe()
# Out:
# count    1000.000000
# mean        5.314222
# std        14.465650
# min         0.010000
# 25%         0.821625
# 50%         2.064450
# 75%         4.620475
# max       215.620200
# Name: volume, dtype: float64

# %% [markdown]
# ## Question 5

# %% [markdown]
# ### Convert data
# - Convert features and labels to numpy array
# - Convert their data type to "float32"

# %%
y2 = y1.to_numpy()

# %%
y2.dtype
# Out:
# dtype('float64')

# %%
X1 = X.to_numpy()

# %%
X1.dtype
# Out:
# dtype('float64')

# %%
X1 = np.float32(X1)

# %%
X1.dtype
# Out:
# dtype('float32')

# %%
y_actual=np.float32(y2)

# %%
y_actual.dtype
# Out:
# dtype('float32')

# %%
y_actual.shape
# Out:
# (1000,)

# %% [markdown]
# ## Question 6

# %% [markdown]
# ### Normalize data
# - Normalize features
# - Use tf.math.l2_normalize to normalize features
# - You can read more about it here https://www.tensorflow.org/api_docs/python/tf/math/l2_normalize

# %%
features = tf.math.l2_normalize(X1, axis=None, epsilon=1e-12, name=None)

# %%
x = features

# %% [markdown]
# ## Question 7

# %% [markdown]
# ### Define weight and bias
# - Initialize weight and bias with tf.zeros
# - tf.zeros is an initializer that generates tensors initialized to 0
# - Specify the value for shape

# %%
W = tf.zeros(shape=(4, 1)) 
b = tf.zeros(shape=(1))

# %%
W
# Out:
# <tf.Tensor: shape=(4, 1), dtype=float32, numpy=
# array([[0.],
#        [0.],
#        [0.],
#        [0.]], dtype=float32)>

# %%
b
# Out:
# <tf.Tensor: shape=(1,), dtype=float32, numpy=array([0.], dtype=float32)>

# %% [markdown]
# ## Question 8

# %% [markdown]
# ### Get prediction
# - Define a function to get prediction
# - Approach: prediction = (X * W) + b; here is X is features

# %%
@tf.function 
def prediction(features, W, b):
  y_pred = tf.add(tf.matmul(features, W), b)
  return y_pred

# %% [markdown]
# ### Calculate loss
# - Calculate loss using predictions
# - Define a function to calculate loss
# - We are calculating mean squared error

# %%
@tf.function 
def loss(y_actual, y_predicted):
  diff = y_actual - y_predicted
  sqr = tf.square(diff)
  avg = tf.reduce_mean(sqr)
  return avg

# %% [markdown]
# ## Question 9

# %% [markdown]
# ### Define a function to train the model
# 1.   Record all the mathematical steps to calculate Loss
# 2.   Calculate Gradients of Loss w.r.t weights and bias
# 3.   Update Weights and Bias based on gradients and learning rate to minimize loss

# %%
def train(x, y_actual, w, b, learning_rate=0.01):
  # Record mathematical operations on 'tape' to calculate loss
  with tf.GradientTape() as t:
    t.watch([w,b])
    current_prediction = prediction(x, w, b)
    current_loss = loss(y_actual, current_prediction)
    # Calculate Gradients for Loss with respect to Weights and Bias
    dw, db = t.gradient(current_loss,[w, b])
    # Update Weights and Bias
    w = w - learning_rate * dw
    b = b - learning_rate * db
    return w, b

# %% [markdown]
# ## Question 10

# %% [markdown]
# ### Train the model for 100 epochs
# - Observe the training loss at every iteration

# %%
for i in range(100):
  W, b = train(x, y_actual, W, b)
  print('Current Training Loss on iteration', i, loss(y_actual, prediction(x, W, b)).numpy())
# Out:
# Current Training Loss on iteration 0 236.16759
# Current Training Loss on iteration 1 235.09299
# Current Training Loss on iteration 2 234.06102
# Current Training Loss on iteration 3 233.06998
# Current Training Loss on iteration 4 232.11781
# Current Training Loss on iteration 5 231.20381
# Current Training Loss on iteration 6 230.32585
# Current Training Loss on iteration 7 229.48265
# Current Training Loss on iteration 8 228.67297
# Current Training Loss on iteration 9 227.89539
# Current Training Loss on iteration 10 227.14832
# Current Training Loss on iteration 11 226.43114
# Current Training Loss on iteration 12 225.74234
# Current Training Loss on iteration 13 225.0808
# Current Training Loss on iteration 14 224.44553
# Current Training Loss on iteration 15 223.835
# Current Training Loss on iteration 16 223.24931
# Current Training Loss on iteration 17 222.68655
# Current Training Loss on iteration 18 222.14595
# Current Training Loss on iteration 19 221.62688
# Current Training Loss on iteration 20 221.12842
# Current Training Loss on iteration 21 220.6498
# Current Training Loss on iteration 22 220.18993
# Current Training Loss on iteration 23 219.74841
# Current Training Loss on iteration 24 219.32425
# Current Training Loss on iteration 25 218.91705
# Current Training Loss on iteration 26 218.52579
# Current Training Loss on iteration 27 218.15027
# Current Training Loss on iteration 28 217.78957
# Current Training Loss on iteration 29 217.44315
# Current Training Loss on iteration 30 217.11034
# Current Training Loss on iteration 31 216.79077
# Current Training Loss on iteration 32 216.48412
# Current Training Loss on iteration 33 216.18932
# Current Training Loss on iteration 34 215.90611
# Current Training Loss on iteration 35 215.63437
# Current Training Loss on iteration 36 215.37334
# Current Training Loss on iteration 37 215.12263
# Current Training Loss on iteration 38 214.88185
# Current Training Loss on iteration 39 214.65053
# Current Training Loss on iteration 40 214.42859
# Current Training Loss on iteration 41 214.21527
# Current Training Loss on iteration 42 214.01044
# Current Training Loss on iteration 43 213.81369
# Current Training Loss on iteration 44 213.62482
# Current Training Loss on iteration 45 213.44333
# Current Training Loss on iteration 46 213.2691
# Current Training Loss on iteration 47 213.10179
# Current Training Loss on iteration 48 212.94106
# Current Training Loss on iteration 49 212.78687
# Current Training Loss on iteration 50 212.63857
# Current Training Loss on iteration 51 212.4961
# Current Training Loss on iteration 52 212.35948
# Current Training Loss on iteration 53 212.22816
# Current Training Loss on iteration 54 212.10205
# Current Training Loss on iteration 55 211.98093
# Current Training Loss on iteration 56 211.86461
# Current Training Loss on iteration 57 211.75293
# Current Training Loss on iteration 58 211.64558
# Current Training Loss on iteration 59 211.54266
# Current Training Loss on iteration 60 211.44374
# Current Training Loss on iteration 61 211.34874
# Current Training Loss on iteration 62 211.2575
# Current Training Loss on iteration 63 211.16982
# Current Training Loss on iteration 64 211.08572
# Current Training Loss on iteration 65 211.00484
# Current Training Loss on iteration 66 210.92729
# Current Training Loss on iteration 67 210.85278
# Current Training Loss on iteration 68 210.78104
# Current Training Loss on iteration 69 210.71225
# Current Training Loss on iteration 70 210.64633
# Current Training Loss on iteration 71 210.58289
# Current Training Loss on iteration 72 210.52199
# Current Training Loss on iteration 73 210.46347
# Current Training Loss on iteration 74 210.4073
# Current Training Loss on iteration 75 210.3533
# Current Training Loss on iteration 76 210.30153
# Current Training Loss on iteration 77 210.2518
# Current Training Loss on iteration 78 210.204
# Current Training Loss on iteration 79 210.15811
# Current Training Loss on iteration 80 210.1141
# Current Training Loss on iteration 81 210.0717
# Current Training Loss on iteration 82 210.03108
# Current Training Loss on iteration 83 209.99205
# Current Training Loss on iteration 84 209.95453
# Current Training Loss on iteration 85 209.91852
# Current Training Loss on iteration 86 209.88396
# Current Training Loss on iteration 87 209.85075
# Current Training Loss on iteration 88 209.81891
# Current Training Loss on iteration 89 209.78818
# Current Training Loss on iteration 90 209.75874
# Current Training Loss on iteration 91 209.73053
# Current Training Loss on iteration 92 209.70349
# Current Training Loss on iteration 93 209.67744
# Current Training Loss on iteration 94 209.65225
# Current Training Loss on iteration 95 209.62833
# Current Training Loss on iteration 96 209.6052
# Current Training Loss on iteration 97 209.58302
# Current Training Loss on iteration 98 209.56174
# Current Training Loss on iteration 99 209.5413

# %% [markdown]
# ### Observe values of Weight
# - Print the updated values

# %%
W
# Out:
# <tf.Tensor: shape=(4, 1), dtype=float32, numpy=
# array([[0.0547828 ],
#        [0.05488191],
#        [0.05422735],
#        [0.05533117]], dtype=float32)>

# %% [markdown]
# ### Observe values of Bias
# - Print the updated values

# %%
b
# Out:
# <tf.Tensor: shape=(1,), dtype=float32, numpy=array([4.607657], dtype=float32)>

# %%
b.numpy()
# Out:
# array([4.607657], dtype=float32)

# %%
W.numpy()
# Out:
# array([[0.0547828 ],
#        [0.05488191],
#        [0.05422735],
#        [0.05533117]], dtype=float32)
